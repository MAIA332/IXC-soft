# %%
from visual import graph

# %%
g = graph.graphs("/home/lukas/Área de Trabalho/IXC-soft","sample")

# %%
g.hist()

# %%
import json
import matplotlib.pyplot as plt

# %%
 
with open("D:\\IXC-soft\data\sample.json") as file:
    data_ = json.load(file)

# %%
y = [i for i in range(0,len(data_)+1)]

# %%
y

# %%
x = [i["Assunto BD"] for i in data_]

# %%
x

# %% [markdown]
# ## Teste de amostragem

# %%
c = [
    {
    "nome:":"fa",
    "t1":10
    },
    {

    "nome:":"fa2",
    "t1":7
    },
    {
    "nome:":"fa3",
    "t1":5
    },
    {
    "nome:":"fa4",
    "t1":10
    }
]

# %% [markdown]
# ---

# %%
with open("D:\\IXC-soft\data\sample.json") as file:
    data_ = json.load(file)

# %%
a=[i["Assunto BD"] for i in data_]
b= []
for i in a:
    if i not in b: 
        b.append(i)

# %%
a,b

# %%
t = [a.count(i) for i in b]
t

# %%
k = [i for i in range(0,len(a))]
k

# %%
d = [int((a.count(i)*100)/len(a)) for i in b]
d = sorted(d, reverse=True)
d

# %%
z = [0.1]
for i in range(0,len(d)-1):
    z.append(0)
explode = tuple(z)
explode

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.hist(a, bins=range(0, 11), edgecolor='black', rwidth=0.8,align='mid')

plt.xlabel('Assuntos')
plt.ylabel('Frequency')
plt.title('Histograma de assuntos')
plt.xticks(rotation=50)

plt.show()

# %% [markdown]
# ## Testes gerais

# %%
def quit(flag):
    return False

# %%
t ={
    "quit":quit
}

# %%
while True:
    cmd = input("~lk: ")
    a = t[cmd]("")
    
    if a == False:
        break

# %%
import datetime

# %%
str(datetime.datetime.date())

# %% [markdown]
# ## Grafico de asst x data

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

with open("/home/baia-13/Documentos/IXC-soft/data/sample.json") as file:
    data = json.load(file)

# %%
from modules import formatter

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Data_Fechamento', y='Nota_telefone', hue='Assunto BD', data=features, marker='o')
plt.title('Time Series Plot of Nota_telefone Over Time')
plt.xlabel('Date')
plt.ylabel('Nota_telefone')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Data_Fechamento', y='Nota_telefone', hue='Assunto BD', data=features)
plt.title('Bar Plot of Nota_telefone Over Time for Different Assunto BD')
plt.xlabel('Date')
plt.ylabel('Nota_telefone')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
